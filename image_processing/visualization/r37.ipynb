# %%
import matplotlib.pyplot as plt
import numpy as np
import os.path as path
import _pickle as pickle

# %matplotlib inline

# %%
# visualize data points from pre-computed t-SNE pickle
def visualize(tsne_file):
    with open(tsne_file, 'rb') as handle:
        unpickler = pickle.Unpickler(handle)
        projection = unpickler.load()
    
    base = path.basename(tsne_file)
    name = path.splitext(base)[0]
    
    plt.title(name)
    plt.scatter(*projection.T, alpha=0.25)

# %%
visualize('../phocnet_features/r37_features_sub10000_tsne.pickle')

# %%
visualize('../phocnet_features/r37_features_sub10000_ncomps200_tsne.pickle')

# %%
visualize('../phocnet_features/r37_features_sub10000_ncomps150_tsne.pickle')

# %%
visualize('../phocnet_features/r37_features_sub10000_ncomps100_tsne.pickle')

# %%
visualize('../phocnet_features/r37_features_sub10000_ncomps50_tsne.pickle')

# %%
visualize('../phocnet_features/r37_features_sub10000_ncomps25_tsne.pickle')

# %%
visualize('../phocnet_features/r37_phocs_sub10000_tsne.pickle')

# %%
visualize('../phocnet_features/r37_phocs_sub10000_var95_tsne.pickle')

# %%
visualize('../phocnet_features/r37_phocs_sub10000_var90_tsne.pickle')

# %%
visualize('../phocnet_features/r37_phocs_sub10000_var85_tsne.pickle')
